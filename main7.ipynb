# %%
import argparse
import sys
from sentence_transformers import SentenceTransformer
from sentence_transformers_local import models, losses, SentenceTransformerSequential
from models.Transformers import SCCLBert
from learners.cluster import ClusterLearner
from dataloader.dataloader import augment_loader, augment_loader_split

from training import training
#from training_error_analysis import training

from utils.kmeans import get_kmeans_centers
from utils.logger import setup_path
from utils.randomness import set_global_random_seed
import torch
import pandas as pd
import os
from torch import nn

# %%
# !pip install torch
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]='4'

# setting device on GPU if available, else CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print(torch.cuda.device_count())

#Additional Info when using cuda
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
# 1
# Tesla V100-SXM2-32GB-LS
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %%
MODEL_CLASS = {
    "distil": 'distilbert-base-nli-stsb-mean-tokens', 
    "robertabase": 'roberta-base-nli-stsb-mean-tokens',
    "robertalarge": 'roberta-large-nli-stsb-mean-tokens',
    "msmarco": 'distilroberta-base-msmarco-v2',
    "xlm": "xlm-r-distilroberta-base-paraphrase-v1",
    "bertlarge": 'bert-large-nli-stsb-mean-tokens',
    "bertbase": 'bert-base-nli-stsb-mean-tokens',
    "paraphrase": "paraphrase-mpnet-base-v2",
    "paraphrase-distil": "paraphrase-distilroberta-base-v2",
    "paraphrase-Tiny" : "paraphrase-TinyBERT-L6-v2",
    "stanford-sentiment-roberta" : "stanford-sentiment-treebank-roberta.2021-03-11"
}

parser = argparse.ArgumentParser()
# parser.add_argument('--gpuid', nargs="+", type=int, default=[0], help="The list of gpuid, ex:--gpuid 3 1. Negative value means cpu-only")
parser.add_argument('--seed', type=int, default=200, help="")
parser.add_argument('--print_freq', type=float, default=400, help="")  
parser.add_argument('--result_path', type=str, default='./results/')

parser.add_argument('--bert', type=str, default='paraphrase', help="")
#parser.add_argument('--bert', type=str, default='distil', help="")

parser.add_argument('--bert_model', type=str, default='bert-base-uncased', help="")
parser.add_argument('--note', type=str, default='_search_snippets_distil_lre-4_JSD', help="")

# Dataset
# stackoverflow/stackoverflow_true_text
parser.add_argument('--dataset', type=str, default='search_snippets', help="")
#parser.add_argument('--dataset', type=str, default='stackoverflow', help="")
# parser.add_argument('--data_path', type=str, default='./datasets/stackoverflow/')
parser.add_argument('--max_length', type=int, default=32)
parser.add_argument('--train_val_ratio', type=float, default= [0.9, 0.1])

# Data for train and test
# ###### AgNews
# parser.add_argument('--data_path', type=str, default='./datasets/')
# parser.add_argument('--dataname', type=str, default='agnewsdataraw-8000', help="")
# parser.add_argument('--dataname_val', type=str, default='agnewsdataraw-8000', help="")
# parser.add_argument('--num_classes', type=int, default=4, help="")
# ####### SearchSnippets
parser.add_argument('--data_path', type=str, default='./datasets/augmented/contextual_20_2col_bert/')
# ## parser.add_argument('--dataname', type=str, default='train_search_snippets.csv', help="")
# ## parser.add_argument('--dataname_val', type=str, default='test_search_snippets.csv', help="")
# parser.add_argument('--dataname', type=str, default='search_snippets', help="")
# parser.add_argument('--dataname_val', type=str, default='search_snippets', help="")
# parser.add_argument('--num_classes', type=int, default=8, help="")
# ###### StackOverFlow
# parser.add_argument('--data_path', type=str, default='./datasets/stackoverflow/')
# parser.add_argument('--dataname', type=str, default='stackoverflow', help="")
# parser.add_argument('--dataname_val', type=str, default='stackoverflow', help="")
# parser.add_argument('--num_classes', type=int, default=20, help="")
# ###### Biomedical
# parser.add_argument('--data_path', type=str, default='./datasets/biomedical/')
# parser.add_argument('--dataname', type=str, default='biomedical', help="")
# parser.add_argument('--dataname_val', type=str, default='biomedical', help="")
# parser.add_argument('--num_classes', type=int, default=20, help="")
# ######## Tweet
# parser.add_argument('--data_path', type=str, default='./datasets/')
parser.add_argument('--dataname', type=str, default='tweet_remap_label', help="")
parser.add_argument('--dataname_val', type=str, default='tweet_remap_label', help="")
parser.add_argument('--num_classes', type=int, default=89, help="")
# ######## GoogleNewsTS
# parser.add_argument('--data_path', type=str, default='./datasets/')
# parser.add_argument('--dataname', type=str, default='TS', help="")
# parser.add_argument('--dataname_val', type=str, default='TS', help="")
# parser.add_argument('--num_classes', type=int, default=152, help="")
# ######## GoogleNewsT
# parser.add_argument('--data_path', type=str, default='./datasets/')
# parser.add_argument('--dataname', type=str, default='T', help="")
# parser.add_argument('--dataname_val', type=str, default='T', help="")
# parser.add_argument('--num_classes', type=int, default=152, help="")
# ######## GoogleNewsS
# parser.add_argument('--data_path', type=str, default='./datasets/')
# parser.add_argument('--dataname', type=str, default='S', help="")
# parser.add_argument('--dataname_val', type=str, default='S', help="")
# parser.add_argument('--num_classes', type=int, default=152, help="")

# Learning parameters
parser.add_argument('--lr', type=float, default=1e-6, help="") #learning rate
parser.add_argument('--lr_scale', type=int, default=100, help="")
parser.add_argument('--max_iter', type=int, default=30000)
parser.add_argument('--batch_size', type=int, default=256) #batch size

# CNN Setting
#parser.add_argument('--out_channels', type=int, default=768)
#parser.add_argument('--use_cnn', type5yh=str, default='cnn_1')
#parser.add_argument('--use_cnn', type=str, default='cnn_3')
#parser.add_argument('--use_cnn', type=str, default='cnn_5')
#parser.add_argument('--use_cnn', type=str, default='cnn_7')
#parser.add_argument('--use_cnn', type=str, default='cnn_cat')
#parser.add_argument('--use_cnn', type=str, default='cnn_avg')

# Contrastive learning
parser.add_argument('--use_head', type=bool, default=False)
parser.add_argument('--use_normalize', type=bool, default=False)

parser.add_argument('--weighted_local', type=bool, default=False, help="")
#parser.add_argument('--normalize_method', type=str, default='inverse_prob', help="")
parser.add_argument('--normalize_method', type=str, default='none', help="")

parser.add_argument('--contrastive_local_scale', type=float, default=0.00) #scale of contrastive loss
parser.add_argument('--contrastive_global_scale', type=float, default=0.01) #scale of contrastive loss
parser.add_argument('--temperature', type=float, default=0.5, help="temperature required by contrastive loss")
parser.add_argument('--base_temperature', type=float, default=0.1, help="temperature required by contrastive loss")

# Clustering
# default = 0.02
parser.add_argument('--clustering_scale', type=float, default=0.01) #scale of clustering loss
parser.add_argument('--use_perturbation', action='store_true', help="")
parser.add_argument('--alpha', type=float, default=1)

args = parser.parse_args(args=[])
# args.use_gpu = args.gpuid[0] >= 0
args.resPath = None
args.tensorboard = None

# %%
resPath, tensorboard = setup_path(args)
args.resPath, args.tensorboard = resPath, tensorboard
set_global_random_seed(args.seed)

# Dataset loader
train_loader = augment_loader(args)

# torch.cuda.set_device(args.gpuid[0])
# torch.cuda.set_device(device)

# Initialize cluster centers
# by performing k-means after getting embeddings from Sentence-BERT with mean-pooling(defualt)
sbert = SentenceTransformer(MODEL_CLASS[args.bert])
cluster_centers = get_kmeans_centers(sbert, train_loader, args.num_classes) 


# Model
# 1. Transformer model 
# use Huggingface/transformers model (like BERT, RoBERTa, XLNet, XLM-R) for mapping tokens to embeddings
# word_embedding_model = models.Transformer(MODEL_CLASS[args.bert])

word_embedding_model = models.Transformer('sentence-transformers/paraphrase-mpnet-base-v2')
#word_embedding_model = models.Transformer('sentence-transformers/distilbert-base-nli-stsb-mean-tokens')

# model = SentenceTransformer('distilbert-base-nli-mean-tokens')
dimension = word_embedding_model.get_word_embedding_dimension()
# word_embedding_model = torch.nn.DataParallel(word_embedding_model)


# 2. CNN model
# cnn = models.CNN(in_word_embedding_dimension = word_embedding_model.get_word_embedding_dimension(), 
#                  use_cnn = args.use_cnn, out_channels = word_embedding_model.get_word_embedding_dimension())

# 3. Pooling 
# pooling_model = models.Pooling(cnn.get_word_embedding_dimension(),
#                                pooling_mode_mean_tokens=True,
#                                pooling_mode_cls_token=False,
#                                pooling_mode_max_tokens=False)
pooling_model = models.Pooling(dimension,
                               pooling_mode_mean_tokens=True,
                               pooling_mode_cls_token=False,
                               pooling_mode_max_tokens=False, 
                               pooling_mode_weighted_tokens = False)

# 4. Feature extractor 
#feature_extractor = SentenceTransformerSequential(modules=[word_embedding_model, cnn, pooling_model])
feature_extractor = SentenceTransformerSequential(modules=[word_embedding_model, pooling_model], device = 'cuda')

# 5. main model
model = SCCLBert(feature_extractor, cluster_centers=cluster_centers, alpha = args.alpha, use_head = args.use_head)  


# Optimizer 
optimizer = torch.optim.Adam([
    {'params':word_embedding_model.parameters(), 'lr': args.lr*6},
#    {'params':cnn.parameters(), 'lr': args.lr*50},
    {'params':pooling_model.parameters()},
#    {'params':model.head.parameters(), 'lr': args.lr*20},
    {'params':model.cluster_centers, 'lr': args.lr*60}], lr=args.lr)
# # optimizer = torch.optim.Adam(lr=1e-4,params=model.parameters())
# optimizer = torch.optim.AdamW([
#     {'params':word_embedding_model.parameters(), 'lr': args.lr},
# #    {'params':cnn.parameters(), 'lr': args.lr*50},
#     {'params':pooling_model.parameters()},
# #    {'params':model.head.parameters(), 'lr': args.lr*args.lr_scale},
#     {'params':model.cluster_centers, 'lr': args.lr*20}], lr=args.lr)
# # optimizer = torch.optim.Adam(lr=1e-4,params=model.parameters())
print(optimizer)


# Set up the trainer    
learner = ClusterLearner(model, feature_extractor, optimizer, args.temperature, args.base_temperature,
                         args.contrastive_local_scale, args.contrastive_global_scale, args.clustering_scale, use_head = args.use_head, use_normalize = args.use_normalize)
# learner = torch.nn.DataParallel(learner)
learner = learner.cuda()

# split train - validation
if(args.train_val_ratio != -1):
    train_loader, val_loader = augment_loader_split(args)
    training(train_loader, learner, args, val_loader = val_loader)
# normal
else:
    training(train_loader, learner, args)
# Out:
# results path: ./results/SCCL.paraphrase.search_snippets.lr1e-06.lrscale100.tmp0.5.alpha1.seed200/
# all_embeddings:(2472, 768), true_labels:2472, pred_labels:2472
# true_labels tensor([86,  5, 28,  ..., 52, 13, 71])
# pred_labels tensor([25, 88, 66,  ..., 40, 52, 28], dtype=torch.int32)
# Iterations:11, Clustering ACC:0.656, centers:(89, 768)
# initial_cluster_centers =  torch.Size([89, 768])
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 6e-06
#     weight_decay: 0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 1e-06
#     weight_decay: 0
#
# Parameter Group 2
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 5.9999999999999995e-05
#     weight_decay: 0
# )
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# train_sample 0.9 2225
# val_sample 0.1 247
#
# =30000/9=Iterations/Batches
# [0]-----
# contrastive_local_loss:	 1.49995
# contrastive_global_loss:	 0.01470
# clustering_loss:	 0.00050
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 89
# [Representation] Clustering scores: {'NMI': 0.8661505176447416, 'ARI': 0.518616472636438, 'AMI': 0.8247033701877889}
# [Representation] ACC: 0.6400
# [Representation] ACC sklearn: 0.0000
# [Model] Clustering scores: {'NMI': 0.8731683981547065, 'ARI': 0.5382659327082056, 'AMI': 0.8341778315591768}
# [Model] ACC: 0.6517
# [Model] ACC sklearn: 0.0067
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 73
# [Representation] Clustering scores: {'NMI': 0.9047417427789239, 'ARI': 0.5550734499498651, 'AMI': 0.7460598514105639}
# [Representation] ACC: 0.6964
# [Representation] ACC sklearn: 0.0000
# [Model] Clustering scores: {'NMI': 0.9204320552143644, 'ARI': 0.5869857764921619, 'AMI': 0.8007119455493544}
# [Model] ACC: 0.7328
# [Model] ACC sklearn: 0.0121
# [400]-----
# contrastive_local_loss:	 0.75516
# contrastive_global_loss:	 0.00734
# clustering_loss:	 0.00030
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 89
# [Representation] Clustering scores: {'NMI': 0.8515143100317347, 'ARI': 0.4568222405266499, 'AMI': 0.8049668857723852}
# [Representation] ACC: 0.6076
# [Representation] ACC sklearn: 0.0103
# [Model] Clustering scores: {'NMI': 0.8544924989879454, 'ARI': 0.4797608512694895, 'AMI': 0.8093189842052767}
# [Model] ACC: 0.6315
# [Model] ACC sklearn: 0.0067
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 74
# [Representation] Clustering scores: {'NMI': 0.8920881773858665, 'ARI': 0.4944059748608411, 'AMI': 0.7093381364221666}
# [Representation] ACC: 0.6559
# [Representation] ACC sklearn: 0.0081
# [Model] Clustering scores: {'NMI': 0.9062393224385205, 'ARI': 0.5335218337065443, 'AMI': 0.762094263246021}
# [Model] ACC: 0.7126
# [Model] ACC sklearn: 0.0121
# [800]-----
# contrastive_local_loss:	 2.32540
# contrastive_global_loss:	 0.00387
# clustering_loss:	 0.00037
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 89
# [Representation] Clustering scores: {'NMI': 0.8606934723119682, 'ARI': 0.5132777422813215, 'AMI': 0.8171649063101509}
# [Representation] ACC: 0.6643
# [Representation] ACC sklearn: 0.0112
# [Model] Clustering scores: {'NMI': 0.8570356924828967, 'ARI': 0.5100871530201075, 'AMI': 0.8132513456364779}
# [Model] ACC: 0.6652
# [Model] ACC sklearn: 0.0067
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 73
# [Representation] Clustering scores: {'NMI': 0.8891079031252328, 'ARI': 0.5323684890151974, 'AMI': 0.7060312489131514}
# [Representation] ACC: 0.6559
# [Representation] ACC sklearn: 0.0202
# [Model] Clustering scores: {'NMI': 0.9120538339859446, 'ARI': 0.563581637160051, 'AMI': 0.7796167654691815}
# [Model] ACC: 0.7247
# [Model] ACC sklearn: 0.0121
# [1200]-----
# contrastive_local_loss:	 4.71930
# contrastive_global_loss:	 0.00149
# clustering_loss:	 0.00044
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 89
# [Representation] Clustering scores: {'NMI': 0.8661148396872114, 'ARI': 0.5256446667054352, 'AMI': 0.8244629784398493}
# [Representation] ACC: 0.6602
# [Representation] ACC sklearn: 0.0144
# [Model] Clustering scores: {'NMI': 0.8610262119658071, 'ARI': 0.5263925153849297, 'AMI': 0.8188738522121743}
# [Model] ACC: 0.6706
# [Model] ACC sklearn: 0.0067
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 73
# [Representation] Clustering scores: {'NMI': 0.8647496865259181, 'ARI': 0.43358590455309537, 'AMI': 0.6326625220918607}
# [Representation] ACC: 0.6194
# [Representation] ACC sklearn: 0.0040
# [Model] Clustering scores: {'NMI': 0.912042477960065, 'ARI': 0.5688508803157025, 'AMI': 0.7812537128286711}
# [Model] ACC: 0.7206
# [Model] ACC sklearn: 0.0121
# [1600]-----
# contrastive_local_loss:	 6.29363
# contrastive_global_loss:	 0.00090
# clustering_loss:	 0.00073
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 88
# [Representation] Clustering scores: {'NMI': 0.8641999729489296, 'ARI': 0.5278405335512457, 'AMI': 0.8220538356452212}
# [Representation] ACC: 0.6535
# [Representation] ACC sklearn: 0.0076
# [Model] Clustering scores: {'NMI': 0.8621917685883504, 'ARI': 0.5282326339773016, 'AMI': 0.8205958011281151}
# [Model] ACC: 0.6665
# [Model] ACC sklearn: 0.0072
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 73
# [Representation] Clustering scores: {'NMI': 0.8904267241153918, 'ARI': 0.5738821026073383, 'AMI': 0.7103017615034977}
# [Representation] ACC: 0.6761
# [Representation] ACC sklearn: 0.0081
# [Model] Clustering scores: {'NMI': 0.9103077157801471, 'ARI': 0.5629276532031988, 'AMI': 0.777581020974307}
# [Model] ACC: 0.7166
# [Model] ACC sklearn: 0.0121
# [2000]-----
# contrastive_local_loss:	 8.27323
# contrastive_global_loss:	 0.00136
# clustering_loss:	 0.00204
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 88
# [Representation] Clustering scores: {'NMI': 0.8771829670113119, 'ARI': 0.5726016071266221, 'AMI': 0.8395109925685105}
# [Representation] ACC: 0.6912
# [Representation] ACC sklearn: 0.0184
# [Model] Clustering scores: {'NMI': 0.8496588663709929, 'ARI': 0.5107558449675795, 'AMI': 0.8047929509611299}
# [Model] ACC: 0.6472
# [Model] ACC sklearn: 0.0067
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 69
# [Representation] Clustering scores: {'NMI': 0.8941282156287575, 'ARI': 0.5848035045369271, 'AMI': 0.72586989337903}
# [Representation] ACC: 0.6761
# [Representation] ACC sklearn: 0.0000
# [Model] Clustering scores: {'NMI': 0.9100559946708596, 'ARI': 0.5704961298616604, 'AMI': 0.7816661935817595}
# [Model] ACC: 0.7287
# [Model] ACC sklearn: 0.0121
# [2400]-----
# contrastive_local_loss:	 11.16406
# contrastive_global_loss:	 0.00155
# clustering_loss:	 0.00311
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 84
# [Representation] Clustering scores: {'NMI': 0.8912541821097205, 'ARI': 0.7458234691283758, 'AMI': 0.859757607311845}
# [Representation] ACC: 0.7546
# [Representation] ACC sklearn: 0.0130
# [Model] Clustering scores: {'NMI': 0.8574254532933259, 'ARI': 0.6465067391767281, 'AMI': 0.8183553774018055}
# [Model] ACC: 0.7155
# [Model] ACC sklearn: 0.0058
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 67
# [Representation] Clustering scores: {'NMI': 0.9039276870583816, 'ARI': 0.6754920302265723, 'AMI': 0.7596444537157134}
# [Representation] ACC: 0.7490
# [Representation] ACC sklearn: 0.0000
# [Model] Clustering scores: {'NMI': 0.9093168748516064, 'ARI': 0.6368433636228797, 'AMI': 0.7880582526075092}
# [Model] ACC: 0.7530
# [Model] ACC sklearn: 0.0121
# [2800]-----
# contrastive_local_loss:	 13.31833
# contrastive_global_loss:	 0.00179
# clustering_loss:	 0.00445
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 75
# [Representation] Clustering scores: {'NMI': 0.9109388088604533, 'ARI': 0.7942370749382505, 'AMI': 0.8860056131224958}
# [Representation] ACC: 0.7906
# [Representation] ACC sklearn: 0.0067
# [Model] Clustering scores: {'NMI': 0.8585556431079057, 'ARI': 0.7022379291852975, 'AMI': 0.822587807203223}
# [Model] ACC: 0.7254
# [Model] ACC sklearn: 0.0063
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 60
# [Representation] Clustering scores: {'NMI': 0.9275257092834887, 'ARI': 0.7553696086010363, 'AMI': 0.8219269840614799}
# [Representation] ACC: 0.7976
# [Representation] ACC sklearn: 0.0000
# [Model] Clustering scores: {'NMI': 0.912818173555109, 'ARI': 0.6833542771174735, 'AMI': 0.8036202811436882}
# [Model] ACC: 0.7692
# [Model] ACC sklearn: 0.0121
# [3200]-----
# contrastive_local_loss:	 13.44820
# contrastive_global_loss:	 0.00231
# clustering_loss:	 0.00445
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 66
# [Representation] Clustering scores: {'NMI': 0.9274026978422565, 'ARI': 0.9101075351715607, 'AMI': 0.9083065996181332}
# [Representation] ACC: 0.8670
# [Representation] ACC sklearn: 0.0000
# [Model] Clustering scores: {'NMI': 0.8573226327679683, 'ARI': 0.7455749724501498, 'AMI': 0.8237105370697269}
# [Model] ACC: 0.7308
# [Model] ACC sklearn: 0.0063
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 57
# [Representation] Clustering scores: {'NMI': 0.935334601301708, 'ARI': 0.8061400939116684, 'AMI': 0.8434958663263169}
# [Representation] ACC: 0.8057
# [Representation] ACC sklearn: 0.0081
# [Model] Clustering scores: {'NMI': 0.9030186297444818, 'ARI': 0.6840616574364206, 'AMI': 0.7853150920318553}
# [Model] ACC: 0.7368
# [Model] ACC sklearn: 0.0081
# [3600]-----
# contrastive_local_loss:	 15.17791
# contrastive_global_loss:	 0.00261
# clustering_loss:	 0.00506
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 61
# [Representation] Clustering scores: {'NMI': 0.9264606299307077, 'ARI': 0.9133566057795596, 'AMI': 0.9078064351226713}
# [Representation] ACC: 0.8670
# [Representation] ACC sklearn: 0.0112
# [Model] Clustering scores: {'NMI': 0.8552077398856479, 'ARI': 0.7370898661590441, 'AMI': 0.8224637748816237}
# [Model] ACC: 0.7294
# [Model] ACC sklearn: 0.0054
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 54
# [Representation] Clustering scores: {'NMI': 0.9286763447234115, 'ARI': 0.7616357837736859, 'AMI': 0.8257012620281446}
# [Representation] ACC: 0.7814
# [Representation] ACC sklearn: 0.0040
# [Model] Clustering scores: {'NMI': 0.9017265972183229, 'ARI': 0.6728694628196322, 'AMI': 0.7876649404317115}
# [Model] ACC: 0.7368
# [Model] ACC sklearn: 0.0081
# [4000]-----
# contrastive_local_loss:	 14.17446
# contrastive_global_loss:	 0.00188
# clustering_loss:	 0.00512
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 58
# [Representation] Clustering scores: {'NMI': 0.9307811103519873, 'ARI': 0.9129061492200566, 'AMI': 0.9136599512818648}
# [Representation] ACC: 0.8773
# [Representation] ACC sklearn: 0.0031
# [Model] Clustering scores: {'NMI': 0.8580599733144144, 'ARI': 0.7335379602299856, 'AMI': 0.8270548540001954}
# [Model] ACC: 0.7353
# [Model] ACC sklearn: 0.0058
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 53
# [Representation] Clustering scores: {'NMI': 0.9319051395307143, 'ARI': 0.7816662113329913, 'AMI': 0.8348949916359787}
# [Representation] ACC: 0.7935
# [Representation] ACC sklearn: 0.0081
# [Model] Clustering scores: {'NMI': 0.8967622121087222, 'ARI': 0.6499332592868107, 'AMI': 0.7781049892391496}
# [Model] ACC: 0.7166
# [Model] ACC sklearn: 0.0040
# [4400]-----
# contrastive_local_loss:	 14.28548
# contrastive_global_loss:	 0.00187
# clustering_loss:	 0.00487
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 57
# [Representation] Clustering scores: {'NMI': 0.9272903096373618, 'ARI': 0.908880710508086, 'AMI': 0.9096090735600083}
# [Representation] ACC: 0.8728
# [Representation] ACC sklearn: 0.0207
# [Model] Clustering scores: {'NMI': 0.8595230538152558, 'ARI': 0.7234321141406654, 'AMI': 0.8294562833222853}
# [Model] ACC: 0.7204
# [Model] ACC sklearn: 0.0013
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 51
# [Representation] Clustering scores: {'NMI': 0.9341500844434945, 'ARI': 0.822005105263643, 'AMI': 0.8435026884794321}
# [Representation] ACC: 0.7976
# [Representation] ACC sklearn: 0.0162
# [Model] Clustering scores: {'NMI': 0.9019394156651211, 'ARI': 0.6712301053006128, 'AMI': 0.7911036331655422}
# [Model] ACC: 0.7206
# [Model] ACC sklearn: 0.0000
# [4800]-----
# contrastive_local_loss:	 15.61538
# contrastive_global_loss:	 0.00197
# clustering_loss:	 0.00488
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 54
# [Representation] Clustering scores: {'NMI': 0.9249675962693666, 'ARI': 0.9062377487289984, 'AMI': 0.9070776956970434}
# [Representation] ACC: 0.8593
# [Representation] ACC sklearn: 0.0000
# [Model] Clustering scores: {'NMI': 0.8590647163339196, 'ARI': 0.7137420315807026, 'AMI': 0.8294082198139856}
# [Model] ACC: 0.7231
# [Model] ACC sklearn: 0.0009
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 49
# [Representation] Clustering scores: {'NMI': 0.9229760195877286, 'ARI': 0.7582648578288108, 'AMI': 0.8137361866098592}
# [Representation] ACC: 0.7773
# [Representation] ACC sklearn: 0.0040
# [Model] Clustering scores: {'NMI': 0.9039961472702815, 'ARI': 0.6681968204827101, 'AMI': 0.7970421679693114}
# [Model] ACC: 0.7126
# [Model] ACC sklearn: 0.0000
# [5200]-----
# contrastive_local_loss:	 15.98031
# contrastive_global_loss:	 0.00186
# clustering_loss:	 0.00483
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 51
# [Representation] Clustering scores: {'NMI': 0.9209160575816776, 'ARI': 0.9020885041620164, 'AMI': 0.902503444149622}
# [Representation] ACC: 0.8463
# [Representation] ACC sklearn: 0.0027
# [Model] Clustering scores: {'NMI': 0.8578414025913464, 'ARI': 0.7094415247903487, 'AMI': 0.8288795762707947}
# [Model] ACC: 0.7074
# [Model] ACC sklearn: 0.0018
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 48
# [Representation] Clustering scores: {'NMI': 0.916983163974678, 'ARI': 0.7430966034406705, 'AMI': 0.7994288338587571}
# [Representation] ACC: 0.7652
# [Representation] ACC sklearn: 0.0040
# [Model] Clustering scores: {'NMI': 0.9030939251626126, 'ARI': 0.6766403021715311, 'AMI': 0.7976816565571833}
# [Model] ACC: 0.7287
# [Model] ACC sklearn: 0.0000
# [5600]-----
# contrastive_local_loss:	 15.95435
# contrastive_global_loss:	 0.00192
# clustering_loss:	 0.00500
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 52
# [Representation] Clustering scores: {'NMI': 0.9187489376478483, 'ARI': 0.8993369283823051, 'AMI': 0.9001272962628716}
# [Representation] ACC: 0.8422
# [Representation] ACC sklearn: 0.0040
# [Model] Clustering scores: {'NMI': 0.8542155274242206, 'ARI': 0.6679185728577408, 'AMI': 0.8240679053307443}
# [Model] ACC: 0.6908
# [Model] ACC sklearn: 0.0018
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 49
# [Representation] Clustering scores: {'NMI': 0.9165253372510838, 'ARI': 0.7602258233251677, 'AMI': 0.801154278363756}
# [Representation] ACC: 0.7692
# [Representation] ACC sklearn: 0.0162
# [Model] Clustering scores: {'NMI': 0.8946311055156907, 'ARI': 0.6505104288841801, 'AMI': 0.7786570798336331}
# [Model] ACC: 0.7126
# [Model] ACC sklearn: 0.0000
# [6000]-----
# contrastive_local_loss:	 17.59936
# contrastive_global_loss:	 0.00188
# clustering_loss:	 0.00498
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 51
# [Representation] Clustering scores: {'NMI': 0.9060424202665108, 'ARI': 0.8395529867313133, 'AMI': 0.884966638870189}
# [Representation] ACC: 0.8117
# [Representation] ACC sklearn: 0.0081
# [Model] Clustering scores: {'NMI': 0.8590375955890504, 'ARI': 0.7150546690022036, 'AMI': 0.8306341572937699}
# [Model] ACC: 0.7160
# [Model] ACC sklearn: 0.0022
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 50
# [Representation] Clustering scores: {'NMI': 0.9143628433485329, 'ARI': 0.7571172660039811, 'AMI': 0.796779738471769}
# [Representation] ACC: 0.7611
# [Representation] ACC sklearn: 0.0202
# [Model] Clustering scores: {'NMI': 0.9018903686065278, 'ARI': 0.6722915206935581, 'AMI': 0.7942633456610884}
# [Model] ACC: 0.7287
# [Model] ACC sklearn: 0.0000
# [6400]-----
# contrastive_local_loss:	 16.75338
# contrastive_global_loss:	 0.00173
# clustering_loss:	 0.00511
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 54
# [Representation] Clustering scores: {'NMI': 0.8926133911300635, 'ARI': 0.7692024479354101, 'AMI': 0.8690481257672735}
# [Representation] ACC: 0.7699
# [Representation] ACC sklearn: 0.0184
# [Model] Clustering scores: {'NMI': 0.8500051091415418, 'ARI': 0.6321766081600283, 'AMI': 0.8183140530657986}
# [Model] ACC: 0.6593
# [Model] ACC sklearn: 0.0022
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 49
# [Representation] Clustering scores: {'NMI': 0.9009611401771751, 'ARI': 0.6767218211023651, 'AMI': 0.7611521547416018}
# [Representation] ACC: 0.7368
# [Representation] ACC sklearn: 0.0040
# [Model] Clustering scores: {'NMI': 0.8974058717007118, 'ARI': 0.6540940452095189, 'AMI': 0.7847305121038511}
# [Model] ACC: 0.7166
# [Model] ACC sklearn: 0.0000
# [6800]-----
# contrastive_local_loss:	 17.26166
# contrastive_global_loss:	 0.00190
# clustering_loss:	 0.00531
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 50
# [Representation] Clustering scores: {'NMI': 0.881984578273542, 'ARI': 0.71575393234579, 'AMI': 0.8553122523252992}
# [Representation] ACC: 0.7245
# [Representation] ACC sklearn: 0.0009
# [Model] Clustering scores: {'NMI': 0.8566225420113265, 'ARI': 0.66116639976856, 'AMI': 0.8269816642021146}
# [Model] ACC: 0.6912
# [Model] ACC sklearn: 0.0027
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 50
# [Representation] Clustering scores: {'NMI': 0.9013189173521685, 'ARI': 0.6775362784073782, 'AMI': 0.761328564881131}
# [Representation] ACC: 0.7328
# [Representation] ACC sklearn: 0.0000
# [Model] Clustering scores: {'NMI': 0.8945815865226151, 'ARI': 0.6440159851571473, 'AMI': 0.7778343970964858}
# [Model] ACC: 0.7166
# [Model] ACC sklearn: 0.0040
# [7200]-----
# contrastive_local_loss:	 18.35835
# contrastive_global_loss:	 0.00198
# clustering_loss:	 0.00489
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 50
# [Representation] Clustering scores: {'NMI': 0.8693172945631217, 'ARI': 0.6716079748315158, 'AMI': 0.8374177695278071}
# [Representation] ACC: 0.6989
# [Representation] ACC sklearn: 0.0049
# [Model] Clustering scores: {'NMI': 0.8539734011318058, 'ARI': 0.6447593511604832, 'AMI': 0.8237778841656817}
# [Model] ACC: 0.6715
# [Model] ACC sklearn: 0.0045
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 47
# [Representation] Clustering scores: {'NMI': 0.8903713988904003, 'ARI': 0.6105963944223728, 'AMI': 0.7308267399199}
# [Representation] ACC: 0.7004
# [Representation] ACC sklearn: 0.0324
# [Model] Clustering scores: {'NMI': 0.8929490082132288, 'ARI': 0.6450955452512882, 'AMI': 0.7763210153215201}
# [Model] ACC: 0.7045
# [Model] ACC sklearn: 0.0081
# [7600]-----
# contrastive_local_loss:	 17.49123
# contrastive_global_loss:	 0.00189
# clustering_loss:	 0.00493
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 52
# [Representation] Clustering scores: {'NMI': 0.8545369014335289, 'ARI': 0.5816136207473859, 'AMI': 0.8166865038740759}
# [Representation] ACC: 0.6512
# [Representation] ACC sklearn: 0.0004
# [Model] Clustering scores: {'NMI': 0.8519735316194966, 'ARI': 0.6422977635782533, 'AMI': 0.820762449780579}
# [Model] ACC: 0.6674
# [Model] ACC sklearn: 0.0045
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 49
# [Representation] Clustering scores: {'NMI': 0.8905354752276402, 'ARI': 0.613509688039635, 'AMI': 0.7305394962840898}
# [Representation] ACC: 0.6883
# [Representation] ACC sklearn: 0.0121
# [Model] Clustering scores: {'NMI': 0.8960524750578718, 'ARI': 0.6557583820459006, 'AMI': 0.7809326100141734}
# [Model] ACC: 0.7206
# [Model] ACC sklearn: 0.0081
# [8000]-----
# contrastive_local_loss:	 18.62319
# contrastive_global_loss:	 0.00210
# clustering_loss:	 0.00469
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 54
# [Representation] Clustering scores: {'NMI': 0.8401914865175394, 'ARI': 0.5381056796612096, 'AMI': 0.7970790158720148}
# [Representation] ACC: 0.6328
# [Representation] ACC sklearn: 0.0085
# [Model] Clustering scores: {'NMI': 0.8509307714570596, 'ARI': 0.6323482722442215, 'AMI': 0.8192783588685612}
# [Model] ACC: 0.6566
# [Model] ACC sklearn: 0.0045
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 50
# [Representation] Clustering scores: {'NMI': 0.8800714531415501, 'ARI': 0.5896895217906997, 'AMI': 0.7041921409025916}
# [Representation] ACC: 0.6761
# [Representation] ACC sklearn: 0.0283
# [Model] Clustering scores: {'NMI': 0.8892456128159276, 'ARI': 0.5948898928213029, 'AMI': 0.7614084126661498}
# [Model] ACC: 0.6640
# [Model] ACC sklearn: 0.0081
# [8400]-----
# contrastive_local_loss:	 19.24421
# contrastive_global_loss:	 0.00169
# clustering_loss:	 0.00491
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 52
# [Representation] Clustering scores: {'NMI': 0.8407461396710468, 'ARI': 0.5397351625414879, 'AMI': 0.7968619076040119}
# [Representation] ACC: 0.6247
# [Representation] ACC sklearn: 0.0067
# [Model] Clustering scores: {'NMI': 0.8509401063946185, 'ARI': 0.6438486757919109, 'AMI': 0.8190754668739333}
# [Model] ACC: 0.6517
# [Model] ACC sklearn: 0.0045
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 48
# [Representation] Clustering scores: {'NMI': 0.88060873726685, 'ARI': 0.5735495653046273, 'AMI': 0.7012395519275112}
# [Representation] ACC: 0.6599
# [Representation] ACC sklearn: 0.0081
# [Model] Clustering scores: {'NMI': 0.8935875697044162, 'ARI': 0.6425579768915639, 'AMI': 0.7747996453730029}
# [Model] ACC: 0.6923
# [Model] ACC sklearn: 0.0081
# [8800]-----
# contrastive_local_loss:	 19.45788
# contrastive_global_loss:	 0.00198
# clustering_loss:	 0.00467
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 52
# [Representation] Clustering scores: {'NMI': 0.8269130305705105, 'ARI': 0.5111220888620714, 'AMI': 0.7794388014756509}
# [Representation] ACC: 0.5951
# [Representation] ACC sklearn: 0.0166
# [Model] Clustering scores: {'NMI': 0.8524764170950152, 'ARI': 0.6564747584689393, 'AMI': 0.8212096977853662}
# [Model] ACC: 0.6580
# [Model] ACC sklearn: 0.0045
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 48
# [Representation] Clustering scores: {'NMI': 0.8837691903247658, 'ARI': 0.583441584078418, 'AMI': 0.71065634559834}
# [Representation] ACC: 0.6802
# [Representation] ACC sklearn: 0.0040
# [Model] Clustering scores: {'NMI': 0.8937818399241079, 'ARI': 0.6296803389700467, 'AMI': 0.7744314157034244}
# [Model] ACC: 0.6923
# [Model] ACC sklearn: 0.0081
# [9200]-----
# contrastive_local_loss:	 16.96474
# contrastive_global_loss:	 0.00197
# clustering_loss:	 0.00453
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 52
# [Representation] Clustering scores: {'NMI': 0.8183304665413049, 'ARI': 0.46790591251516034, 'AMI': 0.7675462786992121}
# [Representation] ACC: 0.5622
# [Representation] ACC sklearn: 0.0135
# [Model] Clustering scores: {'NMI': 0.8524629251094971, 'ARI': 0.6528885190918098, 'AMI': 0.8211730985157221}
# [Model] ACC: 0.6454
# [Model] ACC sklearn: 0.0045
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 51
# [Representation] Clustering scores: {'NMI': 0.8731230681056764, 'ARI': 0.5177684790883835, 'AMI': 0.6796576638579124}
# [Representation] ACC: 0.6316
# [Representation] ACC sklearn: 0.0081
# [Model] Clustering scores: {'NMI': 0.8900461332321794, 'ARI': 0.6097928468087037, 'AMI': 0.7629254466318115}
# [Model] ACC: 0.6761
# [Model] ACC sklearn: 0.0081
# [9600]-----
# contrastive_local_loss:	 18.24608
# contrastive_global_loss:	 0.00198
# clustering_loss:	 0.00440
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 52
# [Representation] Clustering scores: {'NMI': 0.8206290799596266, 'ARI': 0.476737712310412, 'AMI': 0.7703950127892099}
# [Representation] ACC: 0.5649
# [Representation] ACC sklearn: 0.0144
# [Model] Clustering scores: {'NMI': 0.8462736652509355, 'ARI': 0.6216989753603023, 'AMI': 0.8129473424732253}
# [Model] ACC: 0.6049
# [Model] ACC sklearn: 0.0036
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 51
# [Representation] Clustering scores: {'NMI': 0.8731141200754832, 'ARI': 0.5212198027109813, 'AMI': 0.681553529139789}
# [Representation] ACC: 0.6437
# [Representation] ACC sklearn: 0.0324
# [Model] Clustering scores: {'NMI': 0.8908894220035225, 'ARI': 0.5910896769043513, 'AMI': 0.7626172453596318}
# [Model] ACC: 0.6478
# [Model] ACC sklearn: 0.0081
# [10000]-----
# contrastive_local_loss:	 20.05516
# contrastive_global_loss:	 0.00197
# clustering_loss:	 0.00448
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 52
# [Representation] Clustering scores: {'NMI': 0.8134832893502955, 'ARI': 0.45660743122574776, 'AMI': 0.7613759806615126}
# [Representation] ACC: 0.5425
# [Representation] ACC sklearn: 0.0126
# [Model] Clustering scores: {'NMI': 0.8451401654837246, 'ARI': 0.6211998937345369, 'AMI': 0.8112131588796638}
# [Model] ACC: 0.6049
# [Model] ACC sklearn: 0.0036
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 52
# [Representation] Clustering scores: {'NMI': 0.8753654499274072, 'ARI': 0.5108428145646688, 'AMI': 0.6824014946606871}
# [Representation] ACC: 0.6397
# [Representation] ACC sklearn: 0.0202
# [Model] Clustering scores: {'NMI': 0.8863280032394926, 'ARI': 0.5760424654213843, 'AMI': 0.7506327389411502}
# [Model] ACC: 0.6356
# [Model] ACC sklearn: 0.0081
# [10400]-----
# contrastive_local_loss:	 21.28248
# contrastive_global_loss:	 0.00169
# clustering_loss:	 0.00472
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 52
# [Representation] Clustering scores: {'NMI': 0.8073982297392084, 'ARI': 0.41116202408776803, 'AMI': 0.750437787642907}
# [Representation] ACC: 0.5070
# [Representation] ACC sklearn: 0.0333
# [Model] Clustering scores: {'NMI': 0.8467908531758601, 'ARI': 0.6263019462770076, 'AMI': 0.8137627389443572}
# [Model] ACC: 0.6058
# [Model] ACC sklearn: 0.0036
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 49
# [Representation] Clustering scores: {'NMI': 0.8699823938489998, 'ARI': 0.4896646439537216, 'AMI': 0.6673257565438253}
# [Representation] ACC: 0.6194
# [Representation] ACC sklearn: 0.0000
# [Model] Clustering scores: {'NMI': 0.8947089541797268, 'ARI': 0.6272855179732881, 'AMI': 0.7747164877760712}
# [Model] ACC: 0.6640
# [Model] ACC sklearn: 0.0081
# [10800]-----
# contrastive_local_loss:	 21.56180
# contrastive_global_loss:	 0.00140
# clustering_loss:	 0.00472
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 53
# [Representation] Clustering scores: {'NMI': 0.8032903327519825, 'ARI': 0.40924619417724456, 'AMI': 0.7456799664260806}
# [Representation] ACC: 0.4993
# [Representation] ACC sklearn: 0.0202
# [Model] Clustering scores: {'NMI': 0.8455560985720068, 'ARI': 0.6222449188737724, 'AMI': 0.8118735605596361}
# [Model] ACC: 0.6031
# [Model] ACC sklearn: 0.0031
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 49
# [Representation] Clustering scores: {'NMI': 0.8736992426222959, 'ARI': 0.5147931187228234, 'AMI': 0.6809621900007596}
# [Representation] ACC: 0.6356
# [Representation] ACC sklearn: 0.0162
# [Model] Clustering scores: {'NMI': 0.888824525346795, 'ARI': 0.6046801118428019, 'AMI': 0.7606597499857473}
# [Model] ACC: 0.6478
# [Model] ACC sklearn: 0.0081
# [11200]-----
# contrastive_local_loss:	 22.38591
# contrastive_global_loss:	 0.00141
# clustering_loss:	 0.00447
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 52
# [Representation] Clustering scores: {'NMI': 0.8078508605561645, 'ARI': 0.43812530175354447, 'AMI': 0.7525623716839213}
# [Representation] ACC: 0.5222
# [Representation] ACC sklearn: 0.0013
# [Model] Clustering scores: {'NMI': 0.8445935680405193, 'ARI': 0.6154205616551628, 'AMI': 0.8106398157053762}
# [Model] ACC: 0.5888
# [Model] ACC sklearn: 0.0031
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 48
# [Representation] Clustering scores: {'NMI': 0.8770403464866355, 'ARI': 0.5374394921036717, 'AMI': 0.6912268810485501}
# [Representation] ACC: 0.6599
# [Representation] ACC sklearn: 0.0000
# [Model] Clustering scores: {'NMI': 0.8914354301571366, 'ARI': 0.5974302151419653, 'AMI': 0.766172785269278}
# [Model] ACC: 0.6478
# [Model] ACC sklearn: 0.0081
# [11600]-----
# contrastive_local_loss:	 24.41366
# contrastive_global_loss:	 0.00147
# clustering_loss:	 0.00443
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 52
# [Representation] Clustering scores: {'NMI': 0.8050126576559898, 'ARI': 0.40677016256521437, 'AMI': 0.7481461700011036}
# [Representation] ACC: 0.4957
# [Representation] ACC sklearn: 0.0139
# [Model] Clustering scores: {'NMI': 0.844719777624656, 'ARI': 0.6144643656000136, 'AMI': 0.8107165276937778}
# [Model] ACC: 0.5910
# [Model] ACC sklearn: 0.0031
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 48
# [Representation] Clustering scores: {'NMI': 0.8761213965706004, 'ARI': 0.5120444914258466, 'AMI': 0.6844632430204313}
# [Representation] ACC: 0.6397
# [Representation] ACC sklearn: 0.0040
# [Model] Clustering scores: {'NMI': 0.8934345923191168, 'ARI': 0.6125231815786117, 'AMI': 0.7716802517821795}
# [Model] ACC: 0.6518
# [Model] ACC sklearn: 0.0081
# [12000]-----
# contrastive_local_loss:	 23.07346
# contrastive_global_loss:	 0.00144
# clustering_loss:	 0.00429
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 52
# [Representation] Clustering scores: {'NMI': 0.8032046520647191, 'ARI': 0.3966149543886501, 'AMI': 0.7438634583895266}
# [Representation] ACC: 0.4881
# [Representation] ACC sklearn: 0.0004
# [Model] Clustering scores: {'NMI': 0.8445398875818337, 'ARI': 0.6117613847900263, 'AMI': 0.8105311573815507}
# [Model] ACC: 0.5780
# [Model] ACC sklearn: 0.0022
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 49
# [Representation] Clustering scores: {'NMI': 0.871084725054267, 'ARI': 0.5159744083786253, 'AMI': 0.6750660413156401}
# [Representation] ACC: 0.6235
# [Representation] ACC sklearn: 0.0121
# [Model] Clustering scores: {'NMI': 0.8929927781673018, 'ARI': 0.6128920692364587, 'AMI': 0.7700999680130773}
# [Model] ACC: 0.6518
# [Model] ACC sklearn: 0.0081
# [12400]-----
# contrastive_local_loss:	 23.30736
# contrastive_global_loss:	 0.00146
# clustering_loss:	 0.00426
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 54
# [Representation] Clustering scores: {'NMI': 0.7970033134474614, 'ARI': 0.3679094947694524, 'AMI': 0.733592666273282}
# [Representation] ACC: 0.4665
# [Representation] ACC sklearn: 0.0000
# [Model] Clustering scores: {'NMI': 0.8440404183490421, 'ARI': 0.6065143162810488, 'AMI': 0.809560431832856}
# [Model] ACC: 0.5784
# [Model] ACC sklearn: 0.0022
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 49
# [Representation] Clustering scores: {'NMI': 0.8733142237366278, 'ARI': 0.496388429935886, 'AMI': 0.6755297620355182}
# [Representation] ACC: 0.6194
# [Representation] ACC sklearn: 0.0607
# [Model] Clustering scores: {'NMI': 0.8907745421877551, 'ARI': 0.6001121073606557, 'AMI': 0.7652694830248944}
# [Model] ACC: 0.6518
# [Model] ACC sklearn: 0.0040
# [12800]-----
# contrastive_local_loss:	 25.63253
# contrastive_global_loss:	 0.00140
# clustering_loss:	 0.00432
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 52
# [Representation] Clustering scores: {'NMI': 0.7935877868122386, 'ARI': 0.3664862555046534, 'AMI': 0.7297285901170815}
# [Representation] ACC: 0.4571
# [Representation] ACC sklearn: 0.0004
# [Model] Clustering scores: {'NMI': 0.8444145378151993, 'ARI': 0.6112229148560038, 'AMI': 0.810241586804565}
# [Model] ACC: 0.5775
# [Model] ACC sklearn: 0.0022
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 48
# [Representation] Clustering scores: {'NMI': 0.8787954318889588, 'ARI': 0.542250937017591, 'AMI': 0.6942292731377492}
# [Representation] ACC: 0.6478
# [Representation] ACC sklearn: 0.0000
# [Model] Clustering scores: {'NMI': 0.8975323338965496, 'ARI': 0.6182977988427159, 'AMI': 0.7805777602325559}
# [Model] ACC: 0.6640
# [Model] ACC sklearn: 0.0081
# [13200]-----
# contrastive_local_loss:	 21.47422
# contrastive_global_loss:	 0.00149
# clustering_loss:	 0.00401
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 54
# [Representation] Clustering scores: {'NMI': 0.794450942336939, 'ARI': 0.37582934628133796, 'AMI': 0.7302158000861094}
# [Representation] ACC: 0.4625
# [Representation] ACC sklearn: 0.0189
# [Model] Clustering scores: {'NMI': 0.8435932701777171, 'ARI': 0.604726264522164, 'AMI': 0.8090010603501772}
# [Model] ACC: 0.5708
# [Model] ACC sklearn: 0.0022
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 49
# [Representation] Clustering scores: {'NMI': 0.8701812854316608, 'ARI': 0.491930741890434, 'AMI': 0.6679625279598086}
# [Representation] ACC: 0.6235
# [Representation] ACC sklearn: 0.0081
# [Model] Clustering scores: {'NMI': 0.8935793885284228, 'ARI': 0.5993985954174843, 'AMI': 0.7705636097666946}
# [Model] ACC: 0.6437
# [Model] ACC sklearn: 0.0040
# [13600]-----
# contrastive_local_loss:	 22.60778
# contrastive_global_loss:	 0.00143
# clustering_loss:	 0.00409
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 53
# [Representation] Clustering scores: {'NMI': 0.7922702575871831, 'ARI': 0.3570706954652874, 'AMI': 0.7283190392760029}
# [Representation] ACC: 0.4530
# [Representation] ACC sklearn: 0.0171
# [Model] Clustering scores: {'NMI': 0.8437857608994302, 'ARI': 0.6031599305025608, 'AMI': 0.8095175082894163}
# [Model] ACC: 0.5717
# [Model] ACC sklearn: 0.0022
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 49
# [Representation] Clustering scores: {'NMI': 0.8622344013981701, 'ARI': 0.4498691119378446, 'AMI': 0.645830330038328}
# [Representation] ACC: 0.5951
# [Representation] ACC sklearn: 0.0202
# [Model] Clustering scores: {'NMI': 0.8896875576894032, 'ARI': 0.6043144667349984, 'AMI': 0.7624551083829784}
# [Model] ACC: 0.6437
# [Model] ACC sklearn: 0.0040
# [14000]-----
# contrastive_local_loss:	 23.58028
# contrastive_global_loss:	 0.00138
# clustering_loss:	 0.00399
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 52
# [Representation] Clustering scores: {'NMI': 0.7919041762586921, 'ARI': 0.3519042627415136, 'AMI': 0.727554917868582}
# [Representation] ACC: 0.4530
# [Representation] ACC sklearn: 0.0279
# [Model] Clustering scores: {'NMI': 0.8417731284473021, 'ARI': 0.5900835811200841, 'AMI': 0.8067080715351431}
# [Model] ACC: 0.5604
# [Model] ACC sklearn: 0.0022
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 49
# [Representation] Clustering scores: {'NMI': 0.8647055181467751, 'ARI': 0.46716476718261357, 'AMI': 0.652196281284384}
# [Representation] ACC: 0.6073
# [Representation] ACC sklearn: 0.0081
# [Model] Clustering scores: {'NMI': 0.8899111854713834, 'ARI': 0.5935674250451042, 'AMI': 0.7627100353670166}
# [Model] ACC: 0.6397
# [Model] ACC sklearn: 0.0040
# [14400]-----
# contrastive_local_loss:	 25.36147
# contrastive_global_loss:	 0.00143
# clustering_loss:	 0.00389
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 52
# [Representation] Clustering scores: {'NMI': 0.7934782132100905, 'ARI': 0.3623628189268932, 'AMI': 0.729774183756295}
# [Representation] ACC: 0.4598
# [Representation] ACC sklearn: 0.0148
# [Model] Clustering scores: {'NMI': 0.8401958918009745, 'ARI': 0.5843819771534801, 'AMI': 0.8045292276241456}
# [Model] ACC: 0.5613
# [Model] ACC sklearn: 0.0022
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 50
# [Representation] Clustering scores: {'NMI': 0.8691482534666363, 'ARI': 0.4982915990711332, 'AMI': 0.6667402935566125}
# [Representation] ACC: 0.6316
# [Representation] ACC sklearn: 0.0486
# [Model] Clustering scores: {'NMI': 0.8846942578772143, 'ARI': 0.5802286128826034, 'AMI': 0.7495757134532642}
# [Model] ACC: 0.6356
# [Model] ACC sklearn: 0.0040
# [14800]-----
# contrastive_local_loss:	 22.82948
# contrastive_global_loss:	 0.00127
# clustering_loss:	 0.00413
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 54
# [Representation] Clustering scores: {'NMI': 0.7966850239507847, 'ARI': 0.37579682086261845, 'AMI': 0.734207171018874}
# [Representation] ACC: 0.4670
# [Representation] ACC sklearn: 0.0067
# [Model] Clustering scores: {'NMI': 0.8399131342126299, 'ARI': 0.577934010916107, 'AMI': 0.8040171569974819}
# [Model] ACC: 0.5613
# [Model] ACC sklearn: 0.0022
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 49
# [Representation] Clustering scores: {'NMI': 0.8622980520564666, 'ARI': 0.42977564610608765, 'AMI': 0.6414705043987325}
# [Representation] ACC: 0.5789
# [Representation] ACC sklearn: 0.0162
# [Model] Clustering scores: {'NMI': 0.888138818172104, 'ARI': 0.5935674250451042, 'AMI': 0.7585842529332609}
# [Model] ACC: 0.6437
# [Model] ACC sklearn: 0.0040
# [15200]-----
# contrastive_local_loss:	 21.35601
# contrastive_global_loss:	 0.00131
# clustering_loss:	 0.00400
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 52
# [Representation] Clustering scores: {'NMI': 0.7940523700705334, 'ARI': 0.3597213601603187, 'AMI': 0.7306435701328712}
# [Representation] ACC: 0.4544
# [Representation] ACC sklearn: 0.0234
# [Model] Clustering scores: {'NMI': 0.8399603325830375, 'ARI': 0.574426431526278, 'AMI': 0.8042327853279453}
# [Model] ACC: 0.5596
# [Model] ACC sklearn: 0.0022
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 51
# [Representation] Clustering scores: {'NMI': 0.8657849453325734, 'ARI': 0.4798657727004971, 'AMI': 0.6565977639534826}
# [Representation] ACC: 0.5951
# [Representation] ACC sklearn: 0.0081
# [Model] Clustering scores: {'NMI': 0.8908064579635555, 'ARI': 0.5964759745860071, 'AMI': 0.7628483218621395}
# [Model] ACC: 0.6437
# [Model] ACC sklearn: 0.0040
# [15600]-----
# contrastive_local_loss:	 21.72941
# contrastive_global_loss:	 0.00133
# clustering_loss:	 0.00379
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 53
# [Representation] Clustering scores: {'NMI': 0.7932997884279931, 'ARI': 0.36480158297041737, 'AMI': 0.729439037486962}
# [Representation] ACC: 0.4580
# [Representation] ACC sklearn: 0.0036
# [Model] Clustering scores: {'NMI': 0.8387554778315979, 'ARI': 0.569705678139647, 'AMI': 0.8024746147609816}
# [Model] ACC: 0.5591
# [Model] ACC sklearn: 0.0022
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 50
# [Representation] Clustering scores: {'NMI': 0.8644368708523273, 'ARI': 0.47766857583985145, 'AMI': 0.6557072439738757}
# [Representation] ACC: 0.6032
# [Representation] ACC sklearn: 0.0081
# [Model] Clustering scores: {'NMI': 0.8866650425833751, 'ARI': 0.5867454742733139, 'AMI': 0.7545554892844136}
# [Model] ACC: 0.6316
# [Model] ACC sklearn: 0.0040
# [16000]-----
# contrastive_local_loss:	 23.06802
# contrastive_global_loss:	 0.00127
# clustering_loss:	 0.00398
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 52
# [Representation] Clustering scores: {'NMI': 0.7935304964863261, 'ARI': 0.3595407002661634, 'AMI': 0.7294048038250341}
# [Representation] ACC: 0.4557
# [Representation] ACC sklearn: 0.0004
# [Model] Clustering scores: {'NMI': 0.8396837172620327, 'ARI': 0.5667936545880661, 'AMI': 0.8038495796644166}
# [Model] ACC: 0.5560
# [Model] ACC sklearn: 0.0022
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 50
# [Representation] Clustering scores: {'NMI': 0.8682470820977852, 'ARI': 0.46513746041532383, 'AMI': 0.6602004442903066}
# [Representation] ACC: 0.6032
# [Representation] ACC sklearn: 0.0243
# [Model] Clustering scores: {'NMI': 0.8829457926658837, 'ARI': 0.5670685959022821, 'AMI': 0.7465322639285638}
# [Model] ACC: 0.6275
# [Model] ACC sklearn: 0.0040
# [16400]-----
# contrastive_local_loss:	 24.50064
# contrastive_global_loss:	 0.00143
# clustering_loss:	 0.00354
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 54
# [Representation] Clustering scores: {'NMI': 0.7960713988592018, 'ARI': 0.3834285641119617, 'AMI': 0.7335636146276261}
# [Representation] ACC: 0.4634
# [Representation] ACC sklearn: 0.0135
# [Model] Clustering scores: {'NMI': 0.8386892116405954, 'ARI': 0.563332196641291, 'AMI': 0.8023976340394945}
# [Model] ACC: 0.5533
# [Model] ACC sklearn: 0.0022
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 51
# [Representation] Clustering scores: {'NMI': 0.8692298965884575, 'ARI': 0.48854880993003647, 'AMI': 0.6652236356172561}
# [Representation] ACC: 0.6113
# [Representation] ACC sklearn: 0.0000
# [Model] Clustering scores: {'NMI': 0.8895365212872895, 'ARI': 0.5852923591762395, 'AMI': 0.759670626528076}
# [Model] ACC: 0.6275
# [Model] ACC sklearn: 0.0040
# [16800]-----
# contrastive_local_loss:	 26.86269
# contrastive_global_loss:	 0.00127
# clustering_loss:	 0.00380
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 52
# [Representation] Clustering scores: {'NMI': 0.7939139955847077, 'ARI': 0.37230427106396885, 'AMI': 0.7301118464951615}
# [Representation] ACC: 0.4625
# [Representation] ACC sklearn: 0.0000
# [Model] Clustering scores: {'NMI': 0.8388045595742987, 'ARI': 0.560439436343156, 'AMI': 0.8027883503936978}
# [Model] ACC: 0.5497
# [Model] ACC sklearn: 0.0022
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 50
# [Representation] Clustering scores: {'NMI': 0.8571785379538139, 'ARI': 0.4104908019472201, 'AMI': 0.6282444416247684}
# [Representation] ACC: 0.5506
# [Representation] ACC sklearn: 0.0121
# [Model] Clustering scores: {'NMI': 0.8875690768836043, 'ARI': 0.5801255561385408, 'AMI': 0.7556492857853844}
# [Model] ACC: 0.6356
# [Model] ACC sklearn: 0.0040
# [17200]-----
# contrastive_local_loss:	 26.33101
# contrastive_global_loss:	 0.00132
# clustering_loss:	 0.00378
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 52
# [Representation] Clustering scores: {'NMI': 0.7939231107357583, 'ARI': 0.37385467185103427, 'AMI': 0.7301824988550313}
# [Representation] ACC: 0.4580
# [Representation] ACC sklearn: 0.0139
# [Model] Clustering scores: {'NMI': 0.8388496368046291, 'ARI': 0.5595867987613028, 'AMI': 0.8028213096619676}
# [Model] ACC: 0.5537
# [Model] ACC sklearn: 0.0022
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 51
# [Representation] Clustering scores: {'NMI': 0.8559662925972014, 'ARI': 0.42038233587554463, 'AMI': 0.6235425328697305}
# [Representation] ACC: 0.5425
# [Representation] ACC sklearn: 0.0040
# [Model] Clustering scores: {'NMI': 0.8861074586173759, 'ARI': 0.5760163277644066, 'AMI': 0.7513082176135158}
# [Model] ACC: 0.6356
# [Model] ACC sklearn: 0.0040
# [17600]-----
# contrastive_local_loss:	 23.18706
# contrastive_global_loss:	 0.00152
# clustering_loss:	 0.00367
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 52
# [Representation] Clustering scores: {'NMI': 0.7908750975819995, 'ARI': 0.35267754224043374, 'AMI': 0.7257954033283227}
# [Representation] ACC: 0.4494
# [Representation] ACC sklearn: 0.0000
# [Model] Clustering scores: {'NMI': 0.8390802004908945, 'ARI': 0.559822577392474, 'AMI': 0.8031924493635839}
# [Model] ACC: 0.5542
# [Model] ACC sklearn: 0.0022
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 50
# [Representation] Clustering scores: {'NMI': 0.8584136906492228, 'ARI': 0.4313328443975165, 'AMI': 0.6323162667296925}
# [Representation] ACC: 0.5749
# [Representation] ACC sklearn: 0.0000
# [Model] Clustering scores: {'NMI': 0.8851995374793622, 'ARI': 0.5754144824346253, 'AMI': 0.7508243291826662}
# [Model] ACC: 0.6437
# [Model] ACC sklearn: 0.0040
# [18000]-----
# contrastive_local_loss:	 25.38123
# contrastive_global_loss:	 0.00123
# clustering_loss:	 0.00376
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 53
# [Representation] Clustering scores: {'NMI': 0.7919647141765439, 'ARI': 0.36405180126579256, 'AMI': 0.7270646894000429}
# [Representation] ACC: 0.4535
# [Representation] ACC sklearn: 0.0503
# [Model] Clustering scores: {'NMI': 0.8390387329674659, 'ARI': 0.5604002843644872, 'AMI': 0.8030905651471665}
# [Model] ACC: 0.5569
# [Model] ACC sklearn: 0.0022
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 50
# [Representation] Clustering scores: {'NMI': 0.865793369223293, 'ARI': 0.4519109249953625, 'AMI': 0.6496906557861729}
# [Representation] ACC: 0.5830
# [Representation] ACC sklearn: 0.0040
# [Model] Clustering scores: {'NMI': 0.8831299731472354, 'ARI': 0.5662167196909075, 'AMI': 0.7460270362908117}
# ...
# [Representation] ACC sklearn: 0.0049
# [Model] Clustering scores: {'NMI': 0.8419057624578283, 'ARI': 0.5783053591592725, 'AMI': 0.8071150190634341}
# [Model] ACC: 0.5879
# [Model] ACC sklearn: 0.0004
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 46
# [Representation] Clustering scores: {'NMI': 0.8613138288983131, 'ARI': 0.4337807520308325, 'AMI': 0.6372229059820289}
# [Representation] ACC: 0.5789
# [Representation] ACC sklearn: 0.0445
# [Model] Clustering scores: {'NMI': 0.890104972980694, 'ARI': 0.5988061581056995, 'AMI': 0.7671318078367135}
# [Model] ACC: 0.6599
# [Model] ACC sklearn: 0.0040
# [24400]-----
# contrastive_local_loss:	 31.37872
# contrastive_global_loss:	 0.00123
# clustering_loss:	 0.00319
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 54
# [Representation] Clustering scores: {'NMI': 0.7893537658522842, 'ARI': 0.34681813357130437, 'AMI': 0.7218780874780847}
# [Representation] ACC: 0.4288
# [Representation] ACC sklearn: 0.0229
# [Model] Clustering scores: {'NMI': 0.8422586842017912, 'ARI': 0.577143893655194, 'AMI': 0.8074567873507429}
# [Model] ACC: 0.5924
# [Model] ACC sklearn: 0.0004
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 49
# [Representation] Clustering scores: {'NMI': 0.8585632941847662, 'ARI': 0.42013106355159097, 'AMI': 0.6284569270088971}
# [Representation] ACC: 0.5668
# [Representation] ACC sklearn: 0.0162
# [Model] Clustering scores: {'NMI': 0.8904852301940842, 'ARI': 0.5950451131006792, 'AMI': 0.7651555239155681}
# [Model] ACC: 0.6559
# [Model] ACC sklearn: 0.0040
# [24800]-----
# contrastive_local_loss:	 29.58968
# contrastive_global_loss:	 0.00101
# clustering_loss:	 0.00325
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 54
# [Representation] Clustering scores: {'NMI': 0.7886340318559669, 'ARI': 0.3470636096280555, 'AMI': 0.7211485694121611}
# [Representation] ACC: 0.4369
# [Representation] ACC sklearn: 0.0310
# [Model] Clustering scores: {'NMI': 0.8393684738822215, 'ARI': 0.5614803013938567, 'AMI': 0.8034857694914058}
# [Model] ACC: 0.5870
# [Model] ACC sklearn: 0.0009
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 49
# [Representation] Clustering scores: {'NMI': 0.8653578847981741, 'ARI': 0.4470519386924279, 'AMI': 0.6482290314711185}
# [Representation] ACC: 0.5830
# [Representation] ACC sklearn: 0.0000
# [Model] Clustering scores: {'NMI': 0.8911699648828311, 'ARI': 0.5981590005813658, 'AMI': 0.7667953170560172}
# [Model] ACC: 0.6599
# [Model] ACC sklearn: 0.0040
# [25200]-----
# contrastive_local_loss:	 33.63527
# contrastive_global_loss:	 0.00121
# clustering_loss:	 0.00301
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 52
# [Representation] Clustering scores: {'NMI': 0.7880695846125404, 'ARI': 0.34738949130689306, 'AMI': 0.7200350062431201}
# [Representation] ACC: 0.4351
# [Representation] ACC sklearn: 0.0449
# [Model] Clustering scores: {'NMI': 0.839663299312472, 'ARI': 0.5506741662762387, 'AMI': 0.8042391547418064}
# [Model] ACC: 0.5834
# [Model] ACC sklearn: 0.0004
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 48
# [Representation] Clustering scores: {'NMI': 0.8635729834809143, 'ARI': 0.4414806735910921, 'AMI': 0.6441110117798051}
# [Representation] ACC: 0.5870
# [Representation] ACC sklearn: 0.0040
# [Model] Clustering scores: {'NMI': 0.8903512545695059, 'ARI': 0.5908527639710327, 'AMI': 0.7655953493340605}
# [Model] ACC: 0.6559
# [Model] ACC sklearn: 0.0040
# [25600]-----
# contrastive_local_loss:	 30.40250
# contrastive_global_loss:	 0.00128
# clustering_loss:	 0.00320
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 54
# [Representation] Clustering scores: {'NMI': 0.7882702948332698, 'ARI': 0.3435099954984539, 'AMI': 0.7205491514357104}
# [Representation] ACC: 0.4364
# [Representation] ACC sklearn: 0.0004
# [Model] Clustering scores: {'NMI': 0.8389450649557624, 'ARI': 0.544880931942308, 'AMI': 0.8030915984800081}
# [Model] ACC: 0.5847
# [Model] ACC sklearn: 0.0004
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 50
# [Representation] Clustering scores: {'NMI': 0.8701667939478539, 'ARI': 0.48319330008637196, 'AMI': 0.6688107249327875}
# [Representation] ACC: 0.6073
# [Representation] ACC sklearn: 0.0000
# [Model] Clustering scores: {'NMI': 0.8841651493603073, 'ARI': 0.5702369677246304, 'AMI': 0.7496147108050976}
# [Model] ACC: 0.6437
# [Model] ACC sklearn: 0.0040
# [26000]-----
# contrastive_local_loss:	 32.94949
# contrastive_global_loss:	 0.00097
# clustering_loss:	 0.00329
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 54
# [Representation] Clustering scores: {'NMI': 0.7910605029311378, 'ARI': 0.35214190307675913, 'AMI': 0.7243496780635134}
# [Representation] ACC: 0.4355
# [Representation] ACC sklearn: 0.0018
# [Model] Clustering scores: {'NMI': 0.838005315096909, 'ARI': 0.5402474068833054, 'AMI': 0.8018708144543059}
# [Model] ACC: 0.5775
# [Model] ACC sklearn: 0.0004
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 49
# [Representation] Clustering scores: {'NMI': 0.8601319391443724, 'ARI': 0.42305382755587395, 'AMI': 0.6330697772898799}
# [Representation] ACC: 0.5709
# [Representation] ACC sklearn: 0.0040
# [Model] Clustering scores: {'NMI': 0.8885679408535925, 'ARI': 0.5728200478974861, 'AMI': 0.7595081707252407}
# [Model] ACC: 0.6437
# [Model] ACC sklearn: 0.0040
# [26400]-----
# contrastive_local_loss:	 31.74330
# contrastive_global_loss:	 0.00110
# clustering_loss:	 0.00314
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 54
# [Representation] Clustering scores: {'NMI': 0.7910319530737432, 'ARI': 0.35457339147672484, 'AMI': 0.7252483908116366}
# [Representation] ACC: 0.4404
# [Representation] ACC sklearn: 0.0094
# [Model] Clustering scores: {'NMI': 0.8379207248696662, 'ARI': 0.540348024325442, 'AMI': 0.8018182081019513}
# [Model] ACC: 0.5775
# [Model] ACC sklearn: 0.0004
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 49
# [Representation] Clustering scores: {'NMI': 0.8641748510582661, 'ARI': 0.4352800776387541, 'AMI': 0.6442046688576742}
# [Representation] ACC: 0.5870
# [Representation] ACC sklearn: 0.0121
# [Model] Clustering scores: {'NMI': 0.8867745891792325, 'ARI': 0.5689432268544727, 'AMI': 0.7554989803662343}
# [Model] ACC: 0.6437
# [Model] ACC sklearn: 0.0040
# [26800]-----
# contrastive_local_loss:	 33.06868
# contrastive_global_loss:	 0.00101
# clustering_loss:	 0.00327
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 54
# [Representation] Clustering scores: {'NMI': 0.7897323733048524, 'ARI': 0.3469202849963514, 'AMI': 0.7224594087019779}
# [Representation] ACC: 0.4364
# [Representation] ACC sklearn: 0.0018
# [Model] Clustering scores: {'NMI': 0.8401048874072524, 'ARI': 0.5565922035868794, 'AMI': 0.804629158149606}
# [Model] ACC: 0.5987
# [Model] ACC sklearn: 0.0004
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 48
# [Representation] Clustering scores: {'NMI': 0.8600698697166147, 'ARI': 0.40959242534740237, 'AMI': 0.6292638053759437}
# [Representation] ACC: 0.5547
# [Representation] ACC sklearn: 0.0081
# [Model] Clustering scores: {'NMI': 0.8877538538828667, 'ARI': 0.5712923100868734, 'AMI': 0.7582432962590065}
# [Model] ACC: 0.6478
# [Model] ACC sklearn: 0.0040
# [27200]-----
# contrastive_local_loss:	 33.68990
# contrastive_global_loss:	 0.00107
# clustering_loss:	 0.00307
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 53
# [Representation] Clustering scores: {'NMI': 0.7898372445617104, 'ARI': 0.3526076588774043, 'AMI': 0.7228016236890994}
# [Representation] ACC: 0.4256
# [Representation] ACC sklearn: 0.0063
# [Model] Clustering scores: {'NMI': 0.8398376518016882, 'ARI': 0.5512846960945906, 'AMI': 0.8044447374267868}
# [Model] ACC: 0.5946
# [Model] ACC sklearn: 0.0004
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 47
# [Representation] Clustering scores: {'NMI': 0.8740253535106275, 'ARI': 0.4959959928111203, 'AMI': 0.676224831516224}
# [Representation] ACC: 0.6356
# [Representation] ACC sklearn: 0.0283
# [Model] Clustering scores: {'NMI': 0.8915083228275797, 'ARI': 0.587380510199924, 'AMI': 0.76870895994676}
# [Model] ACC: 0.6599
# [Model] ACC sklearn: 0.0040
# [27600]-----
# contrastive_local_loss:	 33.23982
# contrastive_global_loss:	 0.00124
# clustering_loss:	 0.00307
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 54
# [Representation] Clustering scores: {'NMI': 0.7909537678233816, 'ARI': 0.35374284932741523, 'AMI': 0.7241976624017374}
# [Representation] ACC: 0.4351
# [Representation] ACC sklearn: 0.0175
# [Model] Clustering scores: {'NMI': 0.8389499313170544, 'ARI': 0.5487005397675161, 'AMI': 0.8030999162715586}
# [Model] ACC: 0.5951
# [Model] ACC sklearn: 0.0004
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 50
# [Representation] Clustering scores: {'NMI': 0.8711736885257246, 'ARI': 0.48453217754728806, 'AMI': 0.6706404897247105}
# [Representation] ACC: 0.6073
# [Representation] ACC sklearn: 0.0081
# [Model] Clustering scores: {'NMI': 0.8865984457057965, 'ARI': 0.5671926635980541, 'AMI': 0.7551020908047572}
# [Model] ACC: 0.6437
# [Model] ACC sklearn: 0.0040
# [28000]-----
# contrastive_local_loss:	 31.86031
# contrastive_global_loss:	 0.00108
# clustering_loss:	 0.00315
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 53
# [Representation] Clustering scores: {'NMI': 0.7916716825007473, 'ARI': 0.35832220298382633, 'AMI': 0.7249894571507273}
# [Representation] ACC: 0.4364
# [Representation] ACC sklearn: 0.0067
# [Model] Clustering scores: {'NMI': 0.8391587009808757, 'ARI': 0.5439632604536723, 'AMI': 0.8034298172763209}
# [Model] ACC: 0.5960
# [Model] ACC sklearn: 0.0004
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 49
# [Representation] Clustering scores: {'NMI': 0.8685945233641442, 'ARI': 0.43842541935339313, 'AMI': 0.6526127868932925}
# [Representation] ACC: 0.5830
# [Representation] ACC sklearn: 0.0081
# [Model] Clustering scores: {'NMI': 0.8886657855807046, 'ARI': 0.5739805294123248, 'AMI': 0.760193765640446}
# [Model] ACC: 0.6478
# [Model] ACC sklearn: 0.0040
# [28400]-----
# contrastive_local_loss:	 35.35743
# contrastive_global_loss:	 0.00097
# clustering_loss:	 0.00307
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 54
# [Representation] Clustering scores: {'NMI': 0.791085483875024, 'ARI': 0.35547452045268946, 'AMI': 0.7246428047950046}
# [Representation] ACC: 0.4378
# [Representation] ACC sklearn: 0.0180
# [Model] Clustering scores: {'NMI': 0.8393576143999283, 'ARI': 0.546803459912189, 'AMI': 0.8038264016479534}
# [Model] ACC: 0.5960
# [Model] ACC sklearn: 0.0004
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 48
# [Representation] Clustering scores: {'NMI': 0.8658800475219846, 'ARI': 0.45058675391243486, 'AMI': 0.6513888051014429}
# [Representation] ACC: 0.5951
# [Representation] ACC sklearn: 0.0081
# [Model] Clustering scores: {'NMI': 0.8905319094230743, 'ARI': 0.5829104704748206, 'AMI': 0.7655123529462143}
# [Model] ACC: 0.6599
# [Model] ACC sklearn: 0.0040
# [28800]-----
# contrastive_local_loss:	 35.71534
# contrastive_global_loss:	 0.00099
# clustering_loss:	 0.00298
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 51
# [Representation] Clustering scores: {'NMI': 0.7934912502288979, 'ARI': 0.36783265810226096, 'AMI': 0.7280219491590113}
# [Representation] ACC: 0.4369
# [Representation] ACC sklearn: 0.0072
# [Model] Clustering scores: {'NMI': 0.8393486042047977, 'ARI': 0.5432413083505879, 'AMI': 0.8038813129473668}
# [Model] ACC: 0.5883
# [Model] ACC sklearn: 0.0004
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 48
# [Representation] Clustering scores: {'NMI': 0.8682668772641343, 'ARI': 0.4507518563335828, 'AMI': 0.6550329566271278}
# [Representation] ACC: 0.5951
# [Representation] ACC sklearn: 0.0081
# [Model] Clustering scores: {'NMI': 0.8895965613803721, 'ARI': 0.5657689345202781, 'AMI': 0.7623864016265578}
# [Model] ACC: 0.6437
# [Model] ACC sklearn: 0.0040
# [29200]-----
# contrastive_local_loss:	 35.68739
# contrastive_global_loss:	 0.00113
# clustering_loss:	 0.00305
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 53
# [Representation] Clustering scores: {'NMI': 0.7915886564767012, 'ARI': 0.3565192617131209, 'AMI': 0.7251709750422329}
# [Representation] ACC: 0.4283
# [Representation] ACC sklearn: 0.0081
# [Model] Clustering scores: {'NMI': 0.8381013460423454, 'ARI': 0.5381844400781913, 'AMI': 0.8020206096784702}
# [Model] ACC: 0.5856
# [Model] ACC sklearn: 0.0004
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 50
# [Representation] Clustering scores: {'NMI': 0.866600475190886, 'ARI': 0.4395774763416865, 'AMI': 0.6486447064670493}
# [Representation] ACC: 0.5749
# [Representation] ACC sklearn: 0.0081
# [Model] Clustering scores: {'NMI': 0.8860990350716531, 'ARI': 0.5617917919901703, 'AMI': 0.7521068026780074}
# [Model] ACC: 0.6437
# [Model] ACC sklearn: 0.0040
# [29600]-----
# contrastive_local_loss:	 29.51626
# contrastive_global_loss:	 0.00102
# clustering_loss:	 0.00305
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 53
# [Representation] Clustering scores: {'NMI': 0.7933595796683848, 'ARI': 0.3658029074850252, 'AMI': 0.7277998679519677}
# [Representation] ACC: 0.4355
# [Representation] ACC sklearn: 0.0135
# [Model] Clustering scores: {'NMI': 0.8375548739094708, 'ARI': 0.5346007631283166, 'AMI': 0.8012732559846166}
# [Model] ACC: 0.5861
# [Model] ACC sklearn: 0.0004
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 49
# [Representation] Clustering scores: {'NMI': 0.8643773259639584, 'ARI': 0.4238404313237062, 'AMI': 0.6391591872642022}
# [Representation] ACC: 0.5749
# [Representation] ACC sklearn: 0.0081
# [Model] Clustering scores: {'NMI': 0.8896960809497757, 'ARI': 0.561521781333647, 'AMI': 0.7602845921505048}
# [Model] ACC: 0.6437
# [Model] ACC sklearn: 0.0040
# [30000]-----
# contrastive_local_loss:	 34.67102
# contrastive_global_loss:	 0.00102
# clustering_loss:	 0.00301
# local_consistency_loss:	 0.00000
# ------------- Evaluate Training Set -------------
# ------------- 9 batches -------------
# all_pred 53
# [Representation] Clustering scores: {'NMI': 0.7925859253667258, 'ARI': 0.37073992613874573, 'AMI': 0.7268641967274165}
# [Representation] ACC: 0.4382
# [Representation] ACC sklearn: 0.0153
# [Model] Clustering scores: {'NMI': 0.8375587003155558, 'ARI': 0.5342046357267489, 'AMI': 0.801258385849261}
# [Model] ACC: 0.5843
# [Model] ACC sklearn: 0.0004
# ------------- Evaluate Validation Set -------------
# ------------- 1 batches -------------
# all_pred 50
# [Representation] Clustering scores: {'NMI': 0.8638237581596159, 'ARI': 0.4254561892720051, 'AMI': 0.6415463696742338}
# [Representation] ACC: 0.5789
# [Representation] ACC sklearn: 0.0000
# [Model] Clustering scores: {'NMI': 0.8856531874796263, 'ARI': 0.5513801744400629, 'AMI': 0.7500539935370683}
# [Model] ACC: 0.6397
# [Model] ACC sklearn: 0.0040

# %% [markdown]
# ######
